# %%
import uxarray as ux
import numpy as np

# %%
gridfile="/Users/max/mesh.mpas.40962.nc"

# %%
atmcpl="/Users/max/ufs.cpld.cpl.hi.atm.2025-11-21-00000.nc"

# %%
uxds = ux.open_dataset(gridfile, atmcpl)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.13/site-packages/xarray/core/duck_array_ops.py:277: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)

# %%
vname = "atmImp_Sa_tbot"

# %%
pdat = uxds[vname].isel(time=0,atmImp_ny=0)

# %%
levels = np.linspace(270, 300, 2)

# %%
pdatplot=(
    pdat.plot.polygons(
        rasterize=True,
        cmap="coolwarm",
    ).opts(width=1400, height=700))

# %%
pdat.plot()
# Out:
# :Image   [x,y]   (x_y atmImp_Sa_tbot)
