# %%
uxds = ux.open_dataset(fmesh, RT+fdata)

pdat = uxds[vname].isel(time=0,atmImp_ny=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 uxds = ux.open_dataset(fmesh, RT+fdata)
#       2
#       3 pdat = uxds[vname].isel(time=0,atmImp_ny=0)
#
# NameError: name 'ux' is not defined

# %%
(pdat.plot.polygons(
        rasterize=True,
        cmap="coolwarm",
    ).opts(width=1400, height=700))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 (pdat.plot.polygons(
#       2         rasterize=True,
#       3         cmap="coolwarm",
#       4     ).opts(width=1400, height=700))
#
# NameError: name 'pdat' is not defined

# %%
import uxarray as ux
RT = "/Users/max/"
fdata = "ufs.cpld.cpl.hi.atm.2025-11-21-00000.nc"
vname = "atmImp_Sa_tbot"
fmesh="/Users/max/mesh.mpas.40962.nc"

# %%
pdatplt=pdat.plot.polygons(
        rasterize=True,
        cmap="coolwarm",
    ).opts(width=1400, height=700)

# %%
bndplt=uxds.uxgrid.plot.edges(color="black", line_width=0.2)

# %%
plot = pdatplt * bndplt

# %%
plot
