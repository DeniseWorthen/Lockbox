# %%
import uxarray as ux
import numpy as np
import cartopy.crs as ccrs

# %%
gridfile="/Users/max/mesh.mpas.40962.nc"

# %%
atmcpl="/Users/max/ufs.cpld.cpl.hi.atm.2025-11-21-00000.nc"

# %%
uxds = ux.open_dataset(gridfile, atmcpl)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.13/site-packages/xarray/core/duck_array_ops.py:277: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)

# %%
vname = "atmImp_Sa_tbot"

# %%
pdat = uxds[vname].isel(time=0,atmImp_ny=0)

# %%
vmin = 980.0

# %%
vmax = 1020.0

# %%
pdatplot = pdat.plot.polygons(
    rasterize=True, 
    cmap="coolwarm",
    #clim=(vmin, vmax),       # Pass it here directly
    colorbar=True
).opts(
    width=900, 
    height=500,
)

# %%
pdatplot
# Out:
# :Image   [x,y]   (x_y atmImp_Sa_tbot)

# %%
pdatplot = pdat.plot.polygons(
    geo=True,                                            # Ensure geographic plotting is on
    projection=ccrs.PlateCarree(central_longitude=240),  # Centers map at 240E, starting left edge at 60E
    rasterize=True, 
    cmap="coolwarm",
    colorbar=True
).opts(
    width=900, 
    height=500,
)

# %%
pdatplot
# Out:
# :Image   [Longitude,Latitude]   (Longitude_Latitude atmImp_Sa_tbot)
